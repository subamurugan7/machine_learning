# %% [markdown]
# <a href="https://colab.research.google.com/github/subamurugan7/machine_learning/blob/main/preprocessing__data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PREPROCESSING DATA

# %% [markdown]
# ## first import in the *libraries*

# %%
import numpy as np

import pandas as pd

# %% [markdown]
# insert the dataset

# %%
dataset=pd.read_csv('california_housing_train.csv')

# %%
print(dataset)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 10433    -120.29     36.88                34.0       1391.0           297.0
# 10434    -120.29     35.56                15.0       4760.0           871.0
# 10435    -120.30     38.90                11.0       1961.0           435.0
# 10436    -120.30     38.04                 6.0       1281.0           245.0
# 10437    -120.30     37.99                23.0       1908.0           383.0
#
# ...

# %% [markdown]
# Building X and Y vectors

# %%
X=dataset.iloc[:,:-1].values

# %%
Y=dataset.iloc[:,-1].values

# %% [markdown]
# print X and Y

# %%
print(X)
# Out:
# [[-1.1431e+02  3.4190e+01  1.5000e+01 ...  1.0150e+03  4.7200e+02
#    1.4936e+00]
#  [-1.1447e+02  3.4400e+01  1.9000e+01 ...  1.1290e+03  4.6300e+02
#    1.8200e+00]
#  [-1.1456e+02  3.3690e+01  1.7000e+01 ...  3.3300e+02  1.1700e+02
#    1.6509e+00]
#  ...
#  [-1.2030e+02  3.8900e+01  1.1000e+01 ...  1.1300e+02  5.3000e+01
#    9.2270e-01]
#  [-1.2030e+02  3.8040e+01  6.0000e+00 ...  4.2200e+02  1.6000e+02
#    3.2875e+00]
#  [-1.2030e+02  3.7990e+01  2.3000e+01 ...  9.8400e+02  3.7400e+02
#    2.5170e+00]]

# %%
print(Y)
# Out:
# [ 66900.  80100.  85700. ...  95500. 111300. 153500.]
